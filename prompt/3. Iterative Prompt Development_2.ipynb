# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# %pip install -U openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI

client = OpenAI()  # 환경변수 OPENAI_API_KEY 필요

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Please write korean language product description for a retail website based on the following technical specifications.
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 3 sentences.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 이 제품은 아름다운 미드 센추리 영감을 받은 사무용 가구 패밀리의 일부로, 책상, 책장, 회의 테이블 등 다양한 제품이 있습니다. 플라스틱 백과 프론트 패브릭 또는 가죽 옵션으로 사용할 수 있으며, 스테인레스 스틸, 매트 블랙, 광택 흰색 또는 크롬 베이스 마감 옵션이 있습니다. 이 의자는 팔걸이 있는지 없는지 선택할 수 있으며, 가정이나 비즈니스 환경에 적합하며 계약 사용에 적합합니다.

# %%
len(response.split(" "))
# Out:
# 56

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Please write korean language product description for a retail website based on the following technical specifications.
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 이 제품은 중세기 영감을 받은 아름다운 가족용 사무용 가구 시리즈의 일부입니다. 다양한 쉘 색상과 베이스 마감 옵션이 있습니다. 플라스틱 뒷면과 앞면 패브릭 또는 가죽 옵션으로 사용할 수 있습니다. 다양한 베이스 마감 옵션과 의자는 팔걸이 있는지 없는지 선택할 수 있습니다. 집이나 사무실에 적합하며 계약 사용에 적합합니다. 이탈리아에서 제조되었습니다.

# %%
len(response.split())
# Out:
# 47

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Please write korean language product description for a retail website based on the following technical specifications.
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 이 제품은 아름다운 미드 센추리 영감을 받은 사무용 가구 패밀리의 일부입니다. 플라스틱 코팅된 알루미늄 베이스와 HD36 폼으로 만들어졌으며 이탈리아에서 생산되었습니다. 다양한 색상 및 베이스 마감 옵션이 있어 가정 또는 비즈니스 환경에 적합합니다.

# %%
prompt = f"""
Please write korean language product description for a retail website based on the following technical specifications.
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 이 제품은 중세기 영감을 받은 사무용 가구 패밀리의 일부로, 다양한 쉘 색상과 베이스 마감 옵션이 있습니다. 플라스틱 뒷면과 앞면 소재 또는 전체 소재로 사용 가능하며, 다양한 패브릭과 가죽 옵션이 있습니다. 안락한 앉음감을 제공하는 소재로 만들어졌습니다. (SWC-100)
#
# Product ID: SWC-100

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Please write korean language product description for a retail website based on the following technical specifications.
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <div>
# <p>이 제품은 아름다운 패밀리 중세기 영감을 받은 사무용 가구 일부입니다.
# 파일 캐비닛, 책상, 책장, 회의 테이블 등이 포함되어 있습니다.
# 쉘 색상과 베이스 마감의 여러 옵션이 있습니다.
# 플라스틱 등백과 전면 소재 (SWC-100) 또는 10가지 패브릭과 6가지 가죽 옵션으로 완전한 소재 (SWC-110)로 제공됩니다.
# 베이스 마감 옵션은 스테인레스 스틸, 매트 블랙, 광택 흰색 또는 크롬이 있습니다.
# 팔걸이 있는지 없는지에 따라 의자를 사용할 수 있습니다.
# 가정이나 비즈니스 환경에 적합합니다.
# 계약 사용에 적합합니다.</p>
#
# <p>구성: 5개의 플라스틱 코팅된 알루미늄 베이스.
# 편압식 의자 조절로 쉬운 높이 조절이 가능합니다.</p>
#
# <p>소재: 캐스트 알루미늄과 수정된 나일론 PA6/PA66 코팅.
# 쉘 두께: 10mm.
# 시트: HD36 폼.</p>
#
# <p>원산지: 이탈리아</p>
#
# <p>제품 ID: SWC-100, SWC-110</p>
# </div>
#
# <table>
#   <caption>Product Dimensions</caption>
#   <tr>
#     <th>WIDTH</th>
#     <td>20.87"</td>
#   </tr>
#   <tr>
#     <th>DEPTH</th>
#     <td>20.08"</td>
#   </tr>
#   <tr>
#     <th>HEIGHT</th>
#     <td>31.50"</td>
#   </tr>
#   <tr>
#     <th>SEAT HEIGHT</th>
#     <td>17.32"</td>
#   </tr>
#   <tr>
#     <th>SEAT DEPTH</th>
#     <td>16.14"</td>
#   </tr>
# </table>

# %%
from IPython.display import display, HTML

display(HTML(response))
# Out:
# <div>
# <p>이 제품은 아름다운 패밀리 중세기 영감을 받은 사무용 가구 일부입니다.
# 파일 캐비닛, 책상, 책장, 회의 테이블 등이 포함되어 있습니다.
# 쉘 색상과 베이스 마감의 여러 옵션이 있습니다.
# 플라스틱 등백과 전면 소재 (SWC-100) 또는 10가지 패브릭과 6가지 가죽 옵션으로 완전한 소재 (SWC-110)로 제공됩니다.
# 베이스 마감 옵션은 스테인레스 스틸, 매트 블랙, 광택 흰색 또는 크롬이 있습니다.
# 팔걸이 있는지 없는지에 따라 의자를 사용할 수 있습니다.
# 가정이나 비즈니스 환경에 적합합니다.
# 계약 사용에 적합합니다.</p>
#
# <p>구성: 5개의 플라스틱 코팅된 알루미늄 베이스.
# 편압식 의자 조절로 쉬운 높이 조절이 가능합니다.</p>
#
# <p>소재: 캐스트 알루미늄과 수정된 나일론 PA6/PA66 코팅.
# 쉘 두께: 10mm.
# 시트: HD36 폼.</p>
#
# <p>원산지: 이탈리아</p>
#
# <p>제품 ID: SWC-100, SWC-110</p>
# </div>
#
# <table>
#   <caption>Product Dimensions</caption>
#   <tr>
#     <th>WIDTH</th>
#     <td>20.87"</td>
#   </tr>
#   <tr>
#     <th>DEPTH</th>
#     <td>20.08"</td>
#   </tr>
#   <tr>
#     <th>HEIGHT</th>
#     <td>31.50"</td>
#   </tr>
#   <tr>
#     <th>SEAT HEIGHT</th>
#     <td>17.32"</td>
#   </tr>
#   <tr>
#     <th>SEAT DEPTH</th>
#     <td>16.14"</td>
#   </tr>
# </table>
